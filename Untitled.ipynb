# %%
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.4     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
data <- read_csv("maternal_health.csv", skip = 1, 
                 col_names = c("age", "systolic_blood_pressure", "diastopic_blood_pressure", "blood_glucose", "body_tempreature", "heart_rate", "risk_level")) |>
                    mutate(risk_level = as_factor(risk_level))
data
# Out:
# Rows: 1014 Columns: 7
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (1): risk_level
# dbl (6): age, systolic_blood_pressure, diastopic_blood_pressure, blood_gluco...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#      age systolic_blood_pressure diastopic_blood_pressure blood_glucose
# 1    25  130                      80                      15.00
# 2    35  140                      90                      13.00
# 3    29   90                      70                       8.00
# 4    30  140                      85                       7.00
# 5    35  120                      60                       6.10
# 6    23  140                      80                       7.01
# 7    23  130                      70                       7.01
# 8    35   85                      60                      11.00
# ...
